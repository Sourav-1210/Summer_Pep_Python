# %%
age = int(input("Enter your age : "))

if(age>=18):
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Eligible to vote

# %%
num = int(input("Enter the number : "))
if(num>0):
    print("num is positive")
else:
    print("num is negative")
# Out:
# num is positive

# %%
salary = int(input("Enter employee salary : "))
if(salary>100000):
    print("Awarded with MacBook pro")
elif(salary>50000):
    print("Awarded with Iphone 17 pro max")
elif(salary>30000):
    print("Awarded with Ipad")
else:
    print("Awarded with Airpodes")
# Out:
# Awarded with Airpodes
